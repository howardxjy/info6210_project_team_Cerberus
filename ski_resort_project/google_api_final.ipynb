# %%
import requests
import json
import googlemaps
import pprint
import time
import pandas as pd
import numpy as np

# %%
csv_file = 'skiResort_usa.csv'
csv_data = pd.read_csv(csv_file)
df_csv=pd.DataFrame(csv_data)

#csv_list = csv_data.tolist()

# %%
csv_data_np = np.array(df_csv)
csv_list = csv_data_np.tolist()

# %%
csv_list[0][0]
# Out:
# '49-degrees-north-mountain-resort'

# %%
re_name_gg = csv_list[:]

# %%
for i in range(len(re_name_gg)):
    re_name_gg[i] = re_name_gg[i][0]

# %%
#re_name_gg = re_name_gg[0:50]

# %%
len(re_name_gg)
# Out:
# 521

# %%
re_name_gg_chg = [x+' skiresort' for x in re_name_gg]

# %%
len(re_name_gg_chg)
# Out:
# 521

# %%
api_key = "AIzaSyAPq4myEXZroJqnvTwZVJNftqW4zyFTf1g"

# %%
gmaps= googlemaps.Client(key= api_key)

# %%
resorts_info=pd.DataFrame()
resorts = re_name_gg_chg[:]
final = []
for x in resorts:
    places_result = gmaps.places(x)
    temp= [x]
    a=places_result['results']
    temp.extend(a)
    final.append(temp)
    #b['gg_name'] = x
    #re_info=pd.DataFrame(b)
    #resorts_info=resorts_info.append(re_info)
    #a.append(temp)
    #re_info=pd.DataFrame(a)
    #ar = np.array(re_info)
    #re_info_list=ar.tolist()
    #re_info_list[0].append(temp)
    #final.append(re_info_list)
    #bb=pd.DataFrame(re_info_list)
    #x_list = pd.DataFrame(temp)
    #merge = pd.merge(re_info, x_list）
    #merge = pd.concat(re_info, x_list）
    #resorts_info=resorts_info.append(bb)
# Out:
# ---------------------------------------------------------------------------
# _OverQueryLimit                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# ...

# %%
final_cp = final[:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-51332b4cd92e> in <module>
# ----> 1 final_cp = final[:]
#
# NameError: name 'final' is not defined

# %%
final_cp[15]
# Out:
# ['american-dream-meadowlands-east-rutherford skiresort',
#  {'formatted_address': '1 Liberty St, New York, NY 10006, USA',
#   'geometry': {'location': {'lat': 40.7097338, 'lng': -74.0109853},
#    'viewport': {'northeast': {'lat': 40.71094427989271,
#      'lng': -74.00974972010728},
#     'southwest': {'lat': 40.70824462010727, 'lng': -74.01244937989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#   'id': '4f8c9eb8fd0f2f26b8008ce7451f4ee7f6541e16',
#   'name': 'Alberta Ski Jumping and Nordic Combined',
#   'place_id': 'ChIJ6Ydr4BlawokRX7cSWoDF4YI',
#   'plus_code': {'compound_code': 'PX5Q+VJ New York, USA',
#    'global_code': '87G7PX5Q+VJ'},
#   'rating': 0,
#   'reference': 'ChIJ6Ydr4BlawokRX7cSWoDF4YI',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 0},
#  {'formatted_address': '50 NJ-120, East Rutherford, NJ 07073, USA',
#   'geometry': {'location': {'lat': 40.8116428, 'lng': -74.0677451},
# ...

# %%
for i in range(len(final_cp)):
    final_cp[i] = final_cp[i][0:2]

# %%
len(final_cp)
# Out:
# 521

# %%
final_cp1=pd.DataFrame(final_cp)

# %%
final_cp_na=final_cp1.dropna(axis=0, how='any')

# %%
final_cp_ar = np.array(final_cp_na)
final_cp_list=final_cp_ar.tolist()

# %%
for i in range(len(final_cp_list)):
    final_cp_list[i][1]['gg_name'] = final_cp_list[i][0]

# %%
len(final_cp_list)
# Out:
# 468

# %%
for i in range(len(final_cp_list)):
    final_cp_list[i]= final_cp_list[i][1]

# %%
final_cp_list
# Out:
# [{'formatted_address': '3311 Flowery Trail Rd, Chewelah, WA 99109, USA',
#   'geometry': {'location': {'lat': 48.3010972, 'lng': -117.5629161},
#    'viewport': {'northeast': {'lat': 48.30274282989273,
#      'lng': -117.5614447201073},
#     'southwest': {'lat': 48.30004317010728, 'lng': -117.5641443798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#   'id': 'a06216f0dc734ac7f19c673b47678c70755aae46',
#   'name': '49° North Mountain Resort',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3265,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112086921004721354049/photos">Lea Hutcheson</a>'],
#     'photo_reference': 'CmRaAAAADIOaC3_fCMX5FoD4xt2T8UiVJ_0cFwR4w-M_R6a6f8qA5V28bzKTlrpC7L_7vnw5wsN4H8E2_KH5D8T0XX8ra1qhMZJ49ucL8X2UumzzuUVglRAbsbgXPaxfVZjtcB75EhDlJgokG2hNnAlzt3vXmPHMGhRcT3iVsuU87fmLlTPTLs0cUxumHw',
#     'width': 4898}],
#   'place_id': 'ChIJ1eQ12RRtYlMRJZGpXHthrXk',
# ...

# %%
resorts_info = pd.DataFrame(final_cp_list)

# %%
resorts_info
# Out:
#                                      formatted_address  \
# 0       3311 Flowery Trail Rd, Chewelah, WA 99109, USA
# 1           390 Pine Hill Rd, Wolfeboro, NH 03894, USA
# 2           6600 Peller Ave S, Hastings, MN 55033, USA
# 3              501 Poplar St, Ishpeming, MI 49849, USA
# 4                        St Albans City, VT 05478, USA
# 5         Arctic Valley Rd, Eagle River, AK 99577, USA
# 6    17800 Alpental Access Rd, Snoqualmie Pass, WA ...
# 7    2600 Alpine Meadows Rd, Alpine Meadows, CA 961...
# 8        10620 Mayfield Rd, Chesterland, OH 44026, USA
# 9                W2501 Co Rd D, Elkhorn, WI 53121, USA
# 10         6775 Highland Rd, White Lake, MI 48383, USA
# 11   10010 Little Cottonwood Canyon Rd, Alta, UT 84...
# 12   56700 Rancheria Rd, Wofford Heights, CA 93285,...
# 13           1000 Arlberg Ave, Girdwood, AK 99587, USA
# 14               1 Liberty St, New York, NY 10006, USA
# 15   8176, 4505 Andes Rd SW, Kensington, MN 56343, ...
# ...

# %%
resorts_info['street'] = resorts_info['formatted_address'].map(lambda x:x.split(',')[0])
resorts_info['city'] = resorts_info['formatted_address'].map(lambda x:x.split(',')[-3])
resorts_info['state&zipcode'] = resorts_info['formatted_address'].map(lambda x:x.split(',')[-2])

# %%
resorts_info
# Out:
#                                      formatted_address  \
# 0       3311 Flowery Trail Rd, Chewelah, WA 99109, USA
# 1           390 Pine Hill Rd, Wolfeboro, NH 03894, USA
# 2           6600 Peller Ave S, Hastings, MN 55033, USA
# 3              501 Poplar St, Ishpeming, MI 49849, USA
# 4                        St Albans City, VT 05478, USA
# 5         Arctic Valley Rd, Eagle River, AK 99577, USA
# 6    17800 Alpental Access Rd, Snoqualmie Pass, WA ...
# 7    2600 Alpine Meadows Rd, Alpine Meadows, CA 961...
# 8        10620 Mayfield Rd, Chesterland, OH 44026, USA
# 9                W2501 Co Rd D, Elkhorn, WI 53121, USA
# 10         6775 Highland Rd, White Lake, MI 48383, USA
# 11   10010 Little Cottonwood Canyon Rd, Alta, UT 84...
# 12   56700 Rancheria Rd, Wofford Heights, CA 93285,...
# 13           1000 Arlberg Ave, Girdwood, AK 99587, USA
# 14               1 Liberty St, New York, NY 10006, USA
# 15   8176, 4505 Andes Rd SW, Kensington, MN 56343, ...
# ...

# %%
re_data = np.array(resorts_info)
re_list = re_data.tolist()

# %%
re_list[0][1]
# Out:
# {'location': {'lat': 48.3010972, 'lng': -117.5629161},
#  'viewport': {'northeast': {'lat': 48.30274282989273,
#    'lng': -117.5614447201073},
#   'southwest': {'lat': 48.30004317010728, 'lng': -117.5641443798927}}}

# %%
resort_geo = re_list[:]
resort_ggid = re_list[:]
resort_ggsearch_name=re_list[:]
resort_name = re_list[:]
resort_opening_hours = re_list[:]
resort_rating = re_list[:]
resort_user_ratings = re_list[:]
resort_loc_street = re_list[:]
resort_loc_city = re_list[:]
resort_loc = re_list[:]
resort_loc_sz = re_list[:]

# %%
for i in range(len(resort_geo)):
    resort_geo[i] = resort_geo[i][1]

# %%
resort_geo_lat = resort_geo[:]
resort_geo_lng = resort_geo[:]

# %%
for i in range(len(resort_geo_lat)):
    resort_geo_lat[i] = resort_geo_lat[i]['location']['lat']
for i in range(len(resort_geo_lng)):
    resort_geo_lng[i] = resort_geo_lng[i]['location']['lng']

# %%
resort_geo_lat
# Out:
# [48.3010972,
#  43.611548,
#  44.8576608,
#  46.5128663,
#  44.8194721,
#  61.24672229999999,
#  47.444154,
#  39.1648486,
#  41.52687,
#  42.7358161,
#  42.6529705,
#  40.5882661,
#  35.7111811,
#  60.9704373,
#  40.7097338,
#  45.850975,
#  36.3876741,
#  44.6121551,
#  44.9993663,
#  33.3973802,
#  36.1744099,
#  43.470944,
#  39.642312,
#  35.330886,
#  39.1822559,
#  39.1862601,
#  44.082771,
#  43.1346697,
#  47.6125783,
#  37.6622677,
#  43.6905069,
#  40.4753327,
#  34.2276705,
#  48.1649918,
#  38.4925588,
#  46.5319811,
#  44.9751148,
#  39.6042863,
#  41.968075,
#  36.1946784,
#  42.1322453,
#  42.622664,
#  41.5232598,
#  41.110006,
#  41.647257,
#  46.5097428,
#  45.2857289,
#  45.5067172,
#  44.16939989999999,
#  46.5224036,
#  42.467159,
#  44.1666812,
#  44.576957,
#  43.0826097,
#  48.0129179,
#  50.6879326,
#  40.2968813,
#  44.5003458,
#  46.0824866,
#  43.7640569,
#  44.42099,
#  39.3364539,
#  41.2640987,
#  48.9512327,
#  42.4192223,
#  40.46152379999999,
# ...

# %%
re_list[0][]

# %%
for i in range(len(resort_ggid)):
    resort_ggid[i] = resort_ggid[i][4]
for i in range(len(resort_ggsearch_name)):
    resort_ggsearch_name[i] = resort_ggsearch_name[i][2]
for i in range(len(resort_name)):
    resort_name[i] = resort_name[i][5]
for i in range(len(resort_opening_hours)):
    resort_opening_hours[i] = resort_opening_hours[i][6]
for i in range(len(resort_rating)):
    resort_rating[i] = resort_rating[i][11]
for i in range(len(resort_user_ratings)):
    resort_user_ratings[i] = resort_user_ratings[i][14]
for i in range(len(resort_loc_street)):
    resort_loc_street[i] = resort_loc_street[i][15]
for i in range(len(resort_loc_city)):
    resort_loc_city[i] = resort_loc_city[i][16]
for i in range(len(resort_loc_sz)):
    resort_loc[i] = resort_loc[i][0]
for i in range(len(resort_loc_sz)):
    resort_loc_sz[i] = resort_loc_sz[i][17]

# %%
resort_opening_hours
# Out:
# [{'open_now': False},
#  nan,
#  nan,
#  {'open_now': True},
#  {},
#  {'open_now': False},
#  {'open_now': False},
#  {'open_now': False},
#  {'open_now': False},
#  nan,
#  {'open_now': False},
#  {'open_now': False},
#  nan,
#  {'open_now': True},
#  nan,
#  {'open_now': False},
#  nan,
#  {'open_now': False},
#  nan,
#  {'open_now': False},
#  {'open_now': True},
#  {'open_now': False},
#  {'open_now': False},
#  {'open_now': False},
#  {'open_now': False},
#  {'open_now': False},
#  {'open_now': True},
#  nan,
#  nan,
#  {'open_now': False},
#  nan,
#  nan,
#  {'open_now': True},
#  nan,
#  nan,
#  nan,
#  {'open_now': False},
#  {'open_now': True},
#  {'open_now': False},
#  {'open_now': True},
#  nan,
#  {'open_now': False},
#  {'open_now': False},
#  {'open_now': True},
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  {'open_now': False},
#  {'open_now': False},
#  {'open_now': True},
#  nan,
#  nan,
#  {'open_now': False},
#  {'open_now': True},
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
resort_loc_city
# Out:
# [' Chewelah',
#  ' Wolfeboro',
#  ' Hastings',
#  ' Ishpeming',
#  'St Albans City',
#  ' Eagle River',
#  ' Snoqualmie Pass',
#  ' Alpine Meadows',
#  ' Chesterland',
#  ' Elkhorn',
#  ' White Lake',
#  ' Alta',
#  ' Wofford Heights',
#  ' Girdwood',
#  ' New York',
#  ' Kensington',
#  ' Angel Fire',
#  ' Dubois',
#  ' North Powder',
#  ' Alto',
#  ' Blowing Rock',
#  ' Freeland',
#  ' Keystone',
#  ' Flagstaff',
#  ' Aspen',
#  ' Aspen',
#  ' Bartlett',
#  ' Sussex',
#  ' East Wenatchee',
#  ' Yosemite National Park',
#  ' Sun Valley',
#  ' Macungie',
#  ' Big Bear Lake',
#  'Havre',
#  ' Bear Valley',
#  ' Fort Ransom',
#  ' Cody',
#  ' Beaver Creek',
#  ' Garden City',
#  ' Beech Mountain',
#  ' Highmount',
#  ' Charlemont',
#  ' Lackawaxen',
#  ' White Haven',
#  ' Chardon',
#  ' Bessemer',
#  ' Big Sky',
#  ' Greenville Junction',
#  ' Tupper Lake',
#  ' Mars Hill',
#  ' Otsego',
#  ' Jackson',
#  ' Rumford',
#  ' Middleton',
#  ' Lakeside',
#  'Warmwell',
#  ' Claysburg',
# ...

# %%
resort_loc_state = resort_loc_sz[:]
resort_loc_zipcode = resort_loc_sz[:]

# %%
for i in range(len(resort_loc_zipcode)):
    resort_loc_zipcode[i] = str(resort_loc_zipcode[i]).split(' ')[2]

# %%
for i in range(len(resort_loc_state)):
    resort_loc_state[i] = str(resort_loc_state[i]).split(' ')[1]

# %%
test_df = pd.DataFrame({"resort_ggid":resort_ggid,"resort_name":resort_name,"resort_ggsearch_name":resort_ggsearch_name,"resort_geo_lat":resort_geo_lat,"resort_geo_lng":resort_geo_lng,"resort_loc_street":resort_loc_street,"resort_loc_city":resort_loc_city,"resort_loc_state":resort_loc_state,"resort_loc_zipcode":resort_loc_zipcode,"resort_rating":resort_rating,"resort_user_ratings":resort_user_ratings,"resort_opening_hours":resort_opening_hours,"resort_loc":resort_loc})

# %%
test_df
# Out:
#                                   resort_ggid  \
# 0    a06216f0dc734ac7f19c673b47678c70755aae46
# 1    efdc4393a9008170e1aaddde304b06fbce455f60
# 2    24b0dd83beeaba95685ced3142809c827cd6b9d4
# 3    4b09b61472cd7d3ac2034554bec1c69b458f234b
# 4    8881d3f45e0c8e0ba7e935b76588b15db12468ec
# 5    ea8a431e81a4066b7b1edb5f2cb3d2783d8d14da
# 6    9bdb16a2d4324ff973471fa62aa3b88e9695a7f6
# 7    680b1caf2408694ea57e57638279e3846b2384f3
# 8    8dc7eb21a00a40cdb4408b526746c65ee2d1623d
# 9    5153c2fb511ead5e2164f00ff23c431eb65859cf
# 10   b457a8f22f6e5ddd0e55e718cc959657bae5cb05
# 11   4dbc30f34f550cc50cb8c4c212f1dc13f833543f
# 12   320f1d5702f5c7b0391682330e0e94c3f889edfb
# 13   c3125dc91adf4a6f0286fce54c1fcd47d59e1528
# 14   4f8c9eb8fd0f2f26b8008ce7451f4ee7f6541e16
# 15   1a3810e034c770f3505dc33ea81a1c391b6cab38
# 16   2b50a45ac27789aef27fe48cc34f17b94e533f97
# 17   82f6c3159eb6132b21fe7da00b0d5946eca3e5c6
# 18   a32452f24d83ab92abe26e05d2df7e80e4f5f564
# ...

# %%
test_df.to_csv('resorts_googleinfo.csv',index=False)
